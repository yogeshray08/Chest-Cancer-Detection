# %%
d = {"key":"value","key1": "value1"}

# %%
d["key"]
# Out:
# 'value'

# %%
d.key
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 d.key
#
# AttributeError: 'dict' object has no attribute 'key'

# %%
from box import ConfigBox

# %%
d2 = {"key":"value","key1": "value1"}
d2
# Out:
# {'key': 'value', 'key1': 'value1'}

# %%
d2 = ConfigBox(d2)

# %%
d2
# Out:
# ConfigBox({'key': 'value', 'key1': 'value1'})

# %%
d2.key1
# Out:
# 'value1'

# %%
def get_product(x:int,y:int):
    return x*y

# %%
get_product(3,"3")
# Out:
# '333'

# %%
import gdown

# %%
url = "https://drive.google.com/file/d/1qGx0Ti30CKj0VDhJqARLY4IrOm_D_Awi/view?usp=sharing"

# %%
file_id = url.split("/")[-2]
file_id
# Out:
# '1qGx0Ti30CKj0VDhJqARLY4IrOm_D_Awi'

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, "Chest-CT-Scan-data.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=1qGx0Ti30CKj0VDhJqARLY4IrOm_D_Awi
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=1qGx0Ti30CKj0VDhJqARLY4IrOm_D_Awi&confirm=t&uuid=ab93b545-96ce-4b17-83c4-ff1dd2bc59dc
# To: /Users/yogeshray/Desktop/Chest-Cancer/Chest-Cancer-Detection/research/Chest-CT-Scan-data.zip
# 100%|██████████| 49.0M/49.0M [00:02<00:00, 20.1MB/s]
# 'Chest-CT-Scan-data.zip'
